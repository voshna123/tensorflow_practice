# %% [markdown]
# <a href="https://colab.research.google.com/github/voshna123/tensorflow_practice/blob/main/FoodRecog_Big_tf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://raw.githubusercontent.com/mrdbourke/tensorflow-deep-learning/refs/heads/main/extras/helper_functions.py
# Out:
# --2025-01-09 03:25:05--  https://raw.githubusercontent.com/mrdbourke/tensorflow-deep-learning/refs/heads/main/extras/helper_functions.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10246 (10K) [text/plain]
# Saving to: ‘helper_functions.py’
#
# helper_functions.py 100%[===================>]  10.01K  --.-KB/s    in 0s
#
# 2025-01-09 03:25:05 (72.4 MB/s) - ‘helper_functions.py’ saved [10246/10246]

# %%
from helper_functions import create_tensorboard_callback, plot_loss_curves,compare_historys,unzip_data

# %% [markdown]
# ## Loading 101Food Dataset

# %%
import tensorflow_datasets as tfds

# %%
(train_data, test_data),ds_info = tfds.load(name = 'food101',
                                            split =['train', 'validation'],
                                            shuffle_files = True,
                                            as_supervised = True,
                                            with_info = True)
# Out:
# Downloading and preparing dataset 4.65 GiB (download: 4.65 GiB, generated: Unknown size, total: 4.65 GiB) to /root/tensorflow_datasets/food101/2.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-b5a1e23df31f> in <cell line: 1>()
# ----> 1 (train_data, test_data),ds_info = tfds.load(name = 'food101',
#       2                                             split =['train', 'validation'],
#       3                                             shuffle_files = True,
#       4                                             as_supervised = True,
#       5                                             with_info = True)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow_datasets/core/logging/__init__.py in __call__(self, function, instance, args, kwargs)
#     174     metadata = self._start_call()
#     175     try:
# --> 176       return function(*args, **kwargs)
#     177     except Exception:
#     178       metadata.mark_error()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow_datasets/core/load.py in load(name, split, data_dir, batch_size, shuffle_files, download, as_supervised, decoders, read_config, with_info, builder_kwargs, download_and_prepare_kwargs, as_dataset_kwargs, try_gcs)
#     659       try_gcs,
#     660   )
# --> 661   _download_and_prepare_builder(dbuilder, download, download_and_prepare_kwargs)
#     662
#     663   if as_dataset_kwargs is None:
#
# /usr/local/lib/python3.10/dist-packages/tensorflow_datasets/core/load.py in _download_and_prepare_builder(dbuilder, download, download_and_prepare_kwargs)
#     515   if download:
#     516     download_and_prepare_kwargs = download_and_prepare_kwargs or {}
# --> 517     dbuilder.download_and_prepare(**download_and_prepare_kwargs)
#     518
#     519
#
# /usr/local/lib/python3.10/dist-packages/tensorflow_datasets/core/logging/__init__.py in __call__(self, function, instance, args, kwargs)
#     174     metadata = self._start_call()
#     175     try:
# --> 176       return function(*args, **kwargs)
#     177     except Exception:
#     178       metadata.mark_error()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow_datasets/core/dataset_builder.py in download_and_prepare(self, download_dir, download_config, file_format, permissions)
#     754           self.info.read_from_directory(self.data_dir)
#     755         else:
# --> 756           self._download_and_prepare(
#     757               dl_manager=dl_manager,
#     758               download_config=download_config,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow_datasets/core/dataset_builder.py in _download_and_prepare(self, dl_manager, download_config)
#    1750       return
#    1751
# -> 1752     split_infos = self._generate_splits(dl_manager, download_config)
#    1753
#    1754     # Update the info object with the splits.
#
# /usr/local/lib/python3.10/dist-packages/tensorflow_datasets/core/dataset_builder.py in _generate_splits(self, dl_manager, download_config)
#    1701       else:
#    1702         optional_pipeline_kwargs = {}
# -> 1703       split_generators = self._split_generators(  # pylint: disable=unexpected-keyword-arg
#    1704           dl_manager, **optional_pipeline_kwargs
#    1705       )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow_datasets/image_classification/food101.py in _split_generators(self, dl_manager)
#      79     """Define Splits."""
#      80
# ---> 81     dl_path = dl_manager.download_and_extract(_BASE_URL)
#      82     meta_path = os.path.join(dl_path, "food-101", "meta")
#      83     image_dir_path = os.path.join(dl_path, "food-101", "images")
#
# /usr/local/lib/python3.10/dist-packages/tensorflow_datasets/core/download/download_manager.py in download_and_extract(self, url_or_urls)
#     746     with self._downloader.tqdm():
#     747       with self._extractor.tqdm():
# --> 748         return _map_promise(self._download_extract, url_or_urls)
#     749
#     750   @property
#
# /usr/local/lib/python3.10/dist-packages/tensorflow_datasets/core/download/download_manager.py in _map_promise(map_fn, all_inputs)
#     774   """Map the function into each element and resolve the promise."""
#     775   all_promises = tree.map_structure(map_fn, all_inputs)  # Apply the function
# --> 776   res = tree.map_structure(lambda p: p.get(), all_promises)  # Wait promises
#     777   return res
#
# /usr/local/lib/python3.10/dist-packages/tree/__init__.py in map_structure(func, *structures, **kwargs)
#     433     assert_same_structure(structures[0], other, check_types=check_types)
#     434   return unflatten_as(structures[0],
# --> 435                       [func(*args) for args in zip(*map(flatten, structures))])
#     436
#     437
#
# /usr/local/lib/python3.10/dist-packages/tree/__init__.py in <listcomp>(.0)
#     433     assert_same_structure(structures[0], other, check_types=check_types)
#     434   return unflatten_as(structures[0],
# --> 435                       [func(*args) for args in zip(*map(flatten, structures))])
#     436
#     437
#
# /usr/local/lib/python3.10/dist-packages/tensorflow_datasets/core/download/download_manager.py in <lambda>(p)
#     774   """Map the function into each element and resolve the promise."""
#     775   all_promises = tree.map_structure(map_fn, all_inputs)  # Apply the function
# --> 776   res = tree.map_structure(lambda p: p.get(), all_promises)  # Wait promises
#     777   return res
#
# /usr/local/lib/python3.10/dist-packages/promise/promise.py in get(self, timeout)
#     509         # type: (Optional[float]) -> T
#     510         target = self._target()
# --> 511         self._wait(timeout or DEFAULT_TIMEOUT)
#     512         return self._target_settled_value(_raise=True)
#     513
#
# /usr/local/lib/python3.10/dist-packages/promise/promise.py in _wait(self, timeout)
#     504     def _wait(self, timeout=None):
#     505         # type: (Optional[float]) -> None
# --> 506         self.wait(self, timeout)
#     507
#     508     def get(self, timeout=None):
#
# /usr/local/lib/python3.10/dist-packages/promise/promise.py in wait(cls, promise, timeout)
#     500     def wait(cls, promise, timeout=None):
#     501         # type: (Promise, Optional[float]) -> None
# --> 502         async_instance.wait(promise, timeout)
#     503
#     504     def _wait(self, timeout=None):
#
# /usr/local/lib/python3.10/dist-packages/promise/async_.py in wait(self, promise, timeout)
#     115                 # fulfilled or rejected
#     116                 return
# --> 117         target.scheduler.wait(target, timeout)
#     118
#     119     def drain_queues(self):
#
# /usr/local/lib/python3.10/dist-packages/promise/schedulers/immediate.py in wait(self, promise, timeout)
#      23
#      24         promise._then(on_resolve_or_reject, on_resolve_or_reject)
# ---> 25         waited = e.wait(timeout)
#      26         if not waited:
#      27             raise Exception("Timeout")
#
# /usr/lib/python3.10/threading.py in wait(self, timeout)
#     605             signaled = self._flag
#     606             if not signaled:
# --> 607                 signaled = self._cond.wait(timeout)
#     608             return signaled
#     609
#
# /usr/lib/python3.10/threading.py in wait(self, timeout)
#     318         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319             if timeout is None:
# --> 320                 waiter.acquire()
#     321                 gotit = True
#     322             else:
#
# KeyboardInterrupt:
